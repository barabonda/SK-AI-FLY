# %% [markdown]
# <a href="https://colab.research.google.com/github/barabonda/SK-AI-FLY/blob/main/%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 가장 기본적인 라인 그래프

# %%
import numpy as np
import matplotlib.pyplot as plt
y = np.arange(0, 10)**3
plt.plot(y)
plt.show()

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

import matplotlib.font_manager as fm
import warnings
warnings.filterwarnings(action='ignore')
path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf' # 나눔 고딕
font_name = fm.FontProperties(fname=path, size=10).get_name() # 기본 폰트 사이즈 : 10
plt.rc('font', family=font_name)
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 39 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
import matplotlib.font_manager as fm
import warnings
warnings.filterwarnings(action='ignore')
path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf' # 나눔 고딕
font_name = fm.FontProperties(fname=path, size=10).get_name() # 기본 폰트 사이즈 : 10
plt.rc('font', family=font_name)

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
x = np.arange(0, 10)
y = x**2
plt.plot(x, y)
plt.title('플롯 그래프')
plt.xlabel('X축')
plt.ylabel('Y축')
plt.show()

# %%
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.sin(x + 0.5)
y3 = np.sin(x + 1)
plt.plot(x, y1, 'r--')
plt.plot(x, y2, 'b.')
plt.plot(x, y3, 'g-.')
plt.title('sin 그래프')
plt.xlabel('X축')
plt.ylabel('Y축')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.sin(x + 0.5)
y3 = np.sin(x + 1)
plt.plot(x, y1, 'r--', label='Sin A')
plt.plot(x, y2, 'b.', label='Sin B')
plt.plot(x, y3, 'g-.', label='Sin C')
plt.title('sin 그래프')
plt.xlabel('X축')
plt.ylabel('Y축')
plt.legend()
plt.show()

# %% [markdown]
# ❖ Figurer과 Axes
# • Matplotlib 객체
# ‣ Figurer 객체, Axes 객체, Axis 객체 등으로 구성
# ‣ Figure 객체는 그림이 그려지는 전체 영역을 말하고, Axes는 하나의 그래프를 의미.
#
#   ‣ Axis는 그래프를 구성하는 x, y축을 의미.
#   ‣ Figure 객체는 한 개 이상의 Axes 객체를 포함.
#   ❖Figure
# ‣ Figure 객체
# ‣ figure() 함수로 생성하거나,
# plot() 함수가 실행되면 자동으로 생성.
# ‣ gcf() 함수로 현재 사용하는 Figure 객체를 얻을 수 있음.
# ‣ 그림의 크기 설정은 Figure 객체를 사용하고, figure() 함수의 figsize 파라미터.
# ‣ gcf() 함수로 Figure 객체를 얻어서, fig.set_size_inches() 함수를 사용

# %%
x = np.random.rand(30)
y = np.random.rand(30)
plt.scatter(x,y)
plt.show()

# %%
x = ['A','B','C','D']
y = [5. , 25. , 50. , 20.]
plt.title('bar 그래프')
plt.xlabel('X축')
plt.ylabel('Y축')
plt.bar(x, y)
plt.show()

# %%
x = ['A','B','C','D']
y = [5. , 25. , 50. , 20.]
plt.barh(x, y)
plt.show()

# %%
name = ['A','B','C','D']
y = [5. , 25. , 50. , 20.]
z = [8. , 20. , 25. , 6.]
fig, ax = plt.subplots(1, 2)
fig.set_size_inches(12, 5) #z크
ax[0].bar(name, y, color='#33aaff')
ax[1].bar(name, z, color=['r', 'g', 'b', 'k'])
plt.show()

# %%
x = np.random.normal(172, 10, 250)
plt.hist(x)
plt.show()

# %%
x = np.random.normal(172, 10, 250)
plt.hist(x, bins=20, color='#05ae1c')
plt.show()

# %%
x = np.random.normal(10, 3, 100)
y = np.random.normal(13, 3, 100)
z = np.random.normal(8, 5, 100)
plt.boxplot([x, y, z])
plt.xticks([1, 2, 3], ['A', 'B', 'C'])
plt.show()
plt.savefig('/box.PNG')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
image = img.imread('/content/R.jpg')
plt.imshow(image)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
x = np.arange(1, 30)
y = np.log(x)
plt.plot(x, y)
fig = plt.gcf()
fig.set_size_inches(8, 6)
plt.savefig('/var/R.jpg')

# %% [markdown]
# 결측치 확인 및 처리
# <br/>
# • 결측치
# <br/>
# ‣ 데이터가 없는 경우
# <br/>
# ‣ 데이터가 없다는 것을 다른 기호로 표시해 놓은 값
# <br/>
# • isna(), isnull()함수
# <br/>
# ‣ 결측치인지 아닌지를 True, False로 표현
# <br/>
# • dropna()
# <br/>
# ‣ 결측치가 포함된 행을 삭제
# <br/>
# • fillna()
# <br/>
# ‣ 결측치를 특정 값으로 변경
#
# **결측값은 평균에 큰 영향을 준다**
# 데이터를 파악하고 도메인의 특성에 따라
# <br/>
# 그때그때 다르게 처리한다.

# %%
import numpy as np
import pandas as pd
z = [['Jackson', 68, True, np.NaN, 'A'],
['Liam', 74, True, 1.1, 'A'],
['Emma', np.NaN, False, 0.89, 'C'],
['James', 78, np.NaN, 0.91, 'C'],
['Ava', 54, False, 0.73, 'C'],
['Henry', 69, True, np.NaN, 'C']]
df = pd.DataFrame(data= z, columns=['Name', 'Weight', 'Option', 'Rate', 'Type'])
df
# Out:
#       Name  Weight Option  Rate Type
# 0  Jackson    68.0   True   NaN    A
# 1     Liam    74.0   True  1.10    A
# 2     Emma     NaN  False  0.89    C
# 3    James    78.0    NaN  0.91    C
# 4      Ava    54.0  False  0.73    C
# 5    Henry    69.0   True   NaN    C

# %%
df.loc[2:4]
# Out:
#     Name  Weight Option  Rate Type
# 2   Emma     NaN  False  0.89    C
# 3  James    78.0    NaN  0.91    C
# 4    Ava    54.0  False  0.73    C

# %%
df.loc[2:4, ['Name','Weight']]
# Out:
#     Name  Weight
# 2   Emma     NaN
# 3  James    78.0
# 4    Ava    54.0

# %%
x = df.loc[df['Option']==True]
print('type : ', type(x))
x
# Out:
# type :  <class 'pandas.core.frame.DataFrame'>
#       Name  Weight Option  Rate Type
# 0  Jackson    68.0   True   NaN    A
# 1     Liam    74.0   True   1.1    A
# 5    Henry    69.0   True   NaN    C

# %%
x = df.loc[df['Rate']>0.8, ['Weight', 'Rate', 'Type']]
x
# Out:
#    Weight  Rate Type
# 1    74.0  1.10    A
# 2     NaN  0.89    C
# 3    78.0  0.91    C

# %%
# !pip install bs4
import requests
from bs4 import BeautifulSoup
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1256 sha256=e8061db2a512f0313d019fad99cbceb533f50cc637cf770996d50216ef7b4211
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# ...

# %%
res = requests.get('http://v.media.daum.net/v/20170615203441266')
print(res.content)
# Out:
# b'<!doctype html>\n<html class="os_window"> \n <head data-cloud-area="head"> \n  <meta charset="utf-8"> \n  <meta http-equiv="X-UA-Compatible" content="IE=edge"> \n  <meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no"> \n  <meta name="format-detection" content="telephone=no"> \n  <meta name="referrer" content="unsafe-url"> \n  <title>\xec\x9e\x94\xea\xb8\x88\xeb\x8c\x80\xec\xb6\x9c\xec\x97\x90\xeb\x8f\x84 DTI \xea\xb7\x9c\xec\xa0\x9c \xec\xa0\x81\xec\x9a\xa9 \xea\xb2\x80\xed\x86\xa0</title> \n  <link rel="shortcut icon" href="//t1.daumcdn.net/top/favicon.ico"> \n  <meta property="mccp:docId" content="nkhSoinQsa"> \n  <meta property="og:site_name" content="\xec\x96\xb8\xeb\xa1\xa0\xec\x82\xac \xeb\xb7\xb0"> \n  <meta property="og:title" content="\xec\x9e\x94\xea\xb8\x88\xeb\x8c\x80\xec\xb6\x9c\xec\x97\x90\xeb\x8f\x84 DTI \xea\xb7\x9c\xec\xa0\x9c \xec\xa0\x81\xec\x9a\xa9 \xea\xb2\x80\xed\x86\xa0"> \n  <meta property="og:regDate" content="
# ...

# %%
soup = BeautifulSoup(res.content, 'html.parser')

# %%
title = soup.find('title')

# %%
print(title.get_text())
# Out:
# 잔금대출에도 DTI 규제 적용 검토

# %%
# !pip install requests
import requests
from bs4 import BeautifulSoup as bs

res = requests.get('https://www.weather.go.kr/w/index.do')
soup = bs(res.content, 'html.parser')
result = soup.select('defs')
data = []
for num in result:
 data.append(int(num.text))
data
# Out:
# ...
# []

# %%
import requests
from bs4 import BeautifulSoup as bs

res = requests.get('https://www.weather.go.kr/w/index.do')
soup = bs(res.content, 'html.parser')
result = soup.select('.tchart')  # Use '.' to specify the class
data = []

for element in result:
    data.append(int(element.text))

print(data)
# Out:
# []

# %%
import requests                  # 웹 페이지의 HTML을 가져오는 모듈
from bs4 import BeautifulSoup    # HTML을 파싱하는 모듈

# 웹 페이지를 가져온 뒤 BeautifulSoup 객체로 만듦
response = requests.get('https://pythondojang.bitbucket.io/weather/observation/currentweather.html')
soup = BeautifulSoup(response.content, 'html.parser')

table = soup.find('table', { 'class': 'table_develop3' })    # <table class="table_develop3">을 찾음
data = []                            # 데이터를 저장할 리스트 생성
for tr in table.find_all('tr'):      # 모든 <tr> 태그를 찾아서 반복(각 지점의 데이터를 가져옴)
    tds = list(tr.find_all('td'))    # 모든 <td> 태그를 찾아서 리스트로 만듦
                                     # (각 날씨 값을 리스트로 만듦)
    for td in tds:                   # <td> 태그 리스트 반복(각 날씨 값을 가져옴)
        if td.find('a'):             # <td> 안에 <a> 태그가 있으면(지점인지 확인)
            point = td.find('a').text    # <a> 태그 안에서 지점을 가져옴
            temperature = tds[5].text    # <td> 태그 리스트의 여섯 번째(인덱스 5)에서 기온을 가져옴
            humidity = tds[9].text       # <td> 태그 리스트의 열 번째(인덱스 9)에서 습도를 가져옴
            data.append([point, temperature, humidity])    # data 리스트에 지점, 기온, 습도를 추가

data    # data 표시. 주피터 노트북에서는 print를 사용하지 않아도 변수의 값이 표시됨
# Out:
# [['서울', '25.6', '30'],
#  ['백령도', '18.4', '62'],
#  ['인천', '20.8', '54'],
#  ['수원', '25.0', '41'],
#  ['동두천', '24.9', '34'],
#  ['파주', '25.1', '39'],
#  ['강화', '20.0', '56'],
#  ['양평', '25.5', '32'],
#  ['이천', '25.6', '28'],
#  ['북춘천', '24.6', '36'],
#  ['북강릉', '19.9', '56'],
#  ['울릉도', '16.8', '77'],
#  ['속초', '19.1', '75'],
#  ['철원', '23.9', '37'],
#  ['대관령', '17.9', '49'],
#  ['춘천', '25.7', '39'],
#  ['강릉', '22.7', '41'],
#  ['동해', '19.5', '77'],
#  ['원주', '23.4', '36'],
#  ['영월', '24.2', '34'],
#  ['인제', '24.3', '31'],
#  ['홍천', '25.4', '25'],
#  ['태백', '19.6', '43'],
#  ['정선군', '23.0', '32'],
#  ['서산', '23.6', '49'],
#  ['청주', '24.3', '33'],
#  ['대전', '25.1', '37'],
#  ['충주', '24.4', '32'],
#  ['추풍령', '23.0', '35'],
#  ['홍성(예)', '24.3', '46'],
#  ['제천', '24.2', '32'],
#  ['보은', '23.7', '28'],
#  ['천안', '23.5', '35'],
#  ['보령', '21.4', '56'],
#  ['부여', '23.9', '37'],
#  ['금산', '23.7', '30'],
#  ['전주', '24.9', '44'],
#  ['광주', '24.0', '35'],
#  ['목포', '22.8', '51'],
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EB%82%A0%EC%94%A8'

# Send a GET request to the URL
res = requests.get(url)

# Check if the request was successful (status code 200)
if res.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(res.content, 'html.parser')

    # Modify the selector to be more specific to the temperature element
    result = soup.select('.blind .todaytemp')

    # Process and print the temperature
    data = [int(temp.text) for temp in result]

    print("Current temperature:", data[0] if data else "Not available")
else:
    print('Failed to retrieve the webpage. Status code:', res.status_code)
# Out:
# Current temperature: Not available

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EB%82%A0%EC%94%A8'

# Send a GET request to the URL
res = requests.get(url)

# Check if the request was successful (status code 200)
if res.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(res.content, 'html.parser')

    # Modify the selector to match the specified structure
    result = soup.select('strong > span.blind')

    # Process and print the temperature value
    temperature = result[0].text.strip() if result else "Not available"

    print("Current temperature:", temperature)
else:
    print('Failed to retrieve the webpage. Status code:', res.status_code)
# Out:
# Current temperature: Not available

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EB%82%A0%EC%94%A8'

# Send a GET request to the URL
res = requests.get(url)

# Check if the request was successful (status code 200)
if res.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(res.content, 'html.parser')

    # Modify the selector to match the class '.celsius'
    result = soup.select('.celsius')

    # Process and print the temperature values
    data = [int(temp.text) for temp in result]

    print("Temperature values:", data)
else:
    print('Failed to retrieve the webpage. Status code:', res.status_code)
# Out:
# Temperature values: []

# %%
from bs4 import beautifulsoup4
from pprint import pprint
import requests

html = requests.get('https://search.naver.com/search.naver?query=날씨')
#웹페이지 요청을 하는 코드이다. 특정 url을 적으면 웹피이지에 대한 소스코드들을 볼 수 있다.

pprint(html.text)
#html 이라는 변수에 저장된 소스코드들 중 텍스트들을 pprint로 정렬한걸 눈으로 확인한다.
soup = BeaoutifulSoup(html.text, 'html.parser')
#파이썬에서 보기 좋게, 다루기 쉽게 파싱작업을 거쳐야 각 요소에 접근이 쉬워진다.
#이것을 도와주는게 beautifulsoup4 모듈이다.
data1 = soup.find('div', {'class':'weather_box'})
#soup 모듈의 find 함수를 사용해서 data1에 값을 저장한다.
#매개변수에는 div 태그명과 class 라는 속성의 값이 weather_box라는 녀석을 딕셔너리로 저장하는 코드이다.
#find 함수를 사용할 때 주의할 점은 같은 웹피이지 소스코드에 같은 소스가 여러가지 있으면 맨 처음 탐색된것만 반환하고 나
find_currenttemp = data1.find('span',{'class': 'todaytemp'}).text
print('현재 온도: '+find_currenttemp+'℃')# 머지는 무시된다는 점이다.
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-85-5aca6b24df34> in <cell line: 1>()
# ----> 1 from bs4 import beautifulsoup4
#       2 from pprint import pprint
#       3 import requests
#       4
#       5 html = requests.get('https://search.naver.com/search.naver?query=날씨')
#
# ImportError: cannot import name 'beautifulsoup4' from 'bs4' (/usr/local/lib/python3.10/dist-packages/bs4/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import requests
from bs4 import BeautifulSoup as bs
res = requests.get('https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EB%82%A0%EC%94%A8')
soup = bs(res.content, 'html.parser')
result = soup.select('blind')
result
data = []
for num in result:
 data.append(num.text)
data
# Out:
# []

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')
print(titanic.head())
print('\n')
print(titanic.info())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
fig = plt.figure(figsize=(15, 5))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)
sns.regplot(x='age', y='survived', data=titanic, ax=ax1)
sns.histplot(x='age',y = 'survived', data=titanic, ax=ax2)
plt.show()

# %%
# 라이브러리 불러오기
import folium
# 서울 지도 만들기
seoul_map = folium.Map(location=[37.55,126.98], zoom_start=12) #위도,경
# 지도를 HTML 파일로 저장하기 #seoul_map.save('./seoul.html’)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
seoul_map3 = folium.Map(location=[37.55,126.98], tiles="Stamen Watercolor", zoom_start=15)
seoul_map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# 지도 중심 경위도 좌표(위도, 경도) 설정하기
lat, lon = 37.504811111562, 127.025492036104
# 줌 설정하기
zoom_size = 15

# folium 지도 생성하기
m = folium.Map(
    location=[lat, lon],
    zoom_start=zoom_size
)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import pandas as pd
df = pd.read_excel('/content/seoulUniv.xlsx', engine= 'openpyxl')
# 서울 지도 만들기
seoul_map = folium.Map(location=[37.55,126.98], zoom_start=12)
# 대학교 위치정보를 Marker로 표시
for name, lat, lng in zip(df.index, df.위도, df.경도):
  folium.Marker([lat, lng], popup=name).add_to(seoul_map)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
for name, lat, lng in zip(df.index, df.위도, df.경도):
 folium.CircleMarker([lat, lng],
radius=10, # 원의 반지름
color='brown', # 원의 둘레 색상
fill=True,
fill_color='coral', # 원을 채우는 색
fill_opacity=0.7, # 투명도
popup=name
 ).add_to(seoul_map)
# 지도를 HTML 파일로 저장하기.
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# !pip install selenium
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 31.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 461.6/461.6 kB 34.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.4 MB/s eta 0:00:00
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By

import pandas as pd
import numpy as np
import time

ser = Service('../chromedriver/chromedriver.exe')
driver = webdriver.Chrome(service = ser)
url = 'https://www.starbucks.co.kr/'
driver.get(url)
# Out:
# ---------------------------------------------------------------------------
# NoSuchDriverException                     Traceback (most recent call last)
# <ipython-input-70-322052fe3772> in <cell line: 11>()
#       9
#      10 ser = Service('../chromedriver/chromedriver.exe')
# ---> 11 driver = webdriver.Chrome(service = ser)
#      12 url = 'https://www.starbucks.co.kr/'
#      13 driver.get(url)
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, options, service, keep_alive)
#      43         options = options if options else Options()
#      44
# ---> 45         super().__init__(
#      46             browser_name=DesiredCapabilities.CHROME["browserName"],
#      47             vendor_prefix="goog",
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      47         self.service = service
#      48
# ...
