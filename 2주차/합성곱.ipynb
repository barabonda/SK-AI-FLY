# %% [markdown]
# <a href="https://colab.research.google.com/github/barabonda/SK-AI-FLY/blob/main/2%EC%A3%BC%EC%B0%A8/%ED%95%A9%EC%84%B1%EA%B3%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 합성곱 신경망(CNN)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 레이어 별로 특징을 뽑아서
# 그다음 weight로 주기
# 특징맵을 쭉 뽑으면
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# relu- softmax이런게
# fully connected이고
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1. convolution layer
# 2. 풀리 커넥티드 레이어
# 반면에 CNN은 미리 고정된 연결이 없음
# 대신 컨볼루션 과정을 통해 출력을 계산.
# → CNN에서 학습하는 것은 바로 필터의 가중치
#
#  사람이 직접 특징필터를 만듬
#  ↓
#  모델 스스로 학습을 통해 특징 추출
#
#     각각 세로와 가로를 판별하는 필터
# → 같은 이미지라도 다른 필터를 거
# 치면 특성 맵에서 추출된 패턴이 달
# 라짐
#
# 컨볼루션에서 필터의 개수만큼 특성 맵이 나온다.
# 그 다음 맥스 풀링으로 특성 맵의 크기를 줄임
#
#   채널 여러개를 이렇게 컨볼루션과 맥스풀링을 하나의 단위로 하여
#   컨볼루션 맥스풀링

# %%
#풀리 커넥티드
#드롭아웃을 쓰면 일부를 잘 인식할 수 있음 픽셀 하난하나
특성 맵의 숫자가 높으면 그 위치가 필터와 유
